# %%
import numpy as np
import random
import matplotlib.pyplot as plt
x = np.arange(0,10,0.1)
y = np.zeros(len(x))
i = 0
while i < len(x):
    y[i] = 5 * x[i] *random.random()
    i = i + 1
plt.plot(x,y)
